# %% [markdown]
# # Re-rank chunks and generate answers
#
# This code demonstrate how to evaluate chunks in parallel generating the percentage of similarity with the question and the answer (part of text in the chunk more appropiate to answer the question).
#
# The output is the chunks more relevant to answer the question and the answer generated with those chunks.
#
# ## Prerequisites
#
# + An Azure subscription, with [access to Azure OpenAI](https://aka.ms/oai/access).
# + An Azure OpenAI service with the service name and an API key.
# + A deployment of the text-embedding-ada-002 embedding model on the Azure OpenAI Service.
# + An Azure AI Search service with the end-point, API Key and the index name to create.
#
# We used Python 3.12.3, [Visual Studio Code with the Python extension](https://code.visualstudio.com/docs/python/python-tutorial), and the [Jupyter extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) to test this example.
#
# ### Set up a Python virtual environment in Visual Studio Code
#
# 1. Open the Command Palette (Ctrl+Shift+P).
# 1. Search for **Python: Create Environment**.
# 1. Select **Venv**.
# 1. Select a Python interpreter. Choose 3.10 or later.
#
# It can take a minute to set up. If you run into problems, see [Python environments in VS Code](https://code.visualstudio.com/docs/python/environments).

# %% [markdown]
# ### Install packages

# %%
! pip install openai
! pip install azure-search-documents

# %% [markdown]
# ## Import packages and create AOAI client

# %%
import os
from dotenv import load_dotenv
from openai import AzureOpenAI
from azure.core.credentials import AzureKeyCredential
from azure.search.documents import SearchClient
import sys
sys.path.append('..')
from pa_utils import calculate_rank, semantic_hybrid_search_with_filter, get_filtered_chunks, generate_answer

# Load environment variables from .env
load_dotenv(override=True)

# AZURE AI SEARCH
ai_search_endpoint = os.environ["SEARCH_SERVICE_ENDPOINT"]
ai_search_apikey = os.environ["SEARCH_SERVICE_QUERY_KEY"]
ai_search_index_name = os.environ["SEARCH_INDEX_NAME"]
ai_search_credential = AzureKeyCredential(ai_search_apikey)
# Create Azure AI Search client
ai_search_client = SearchClient(endpoint=ai_search_endpoint, index_name=ai_search_index_name, credential=ai_search_credential)

aoai_api_version = '2024-02-15-preview'

# AOAI FOR ANSWER GENERATION
aoai_answer_endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]
aoai_answer_apikey = os.environ["AZURE_OPENAI_API_KEY"]
aoai_answer_model_name = os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"]
# Create AOAI client for answer generation
aoai_answer_client = AzureOpenAI(
    azure_deployment=aoai_answer_model_name,
    api_version=aoai_api_version,
    azure_endpoint=aoai_answer_endpoint,
    api_key=aoai_answer_apikey
)

# AZURE OPENAI FOR RERANKING
aoai_rerank_endpoint = os.environ["AZURE_OPENAI_RERANK_ENDPOINT"]
azure_openai_rerank_key = os.environ["AZURE_OPENAI_RERANK_API_KEY"]
rerank_model_name = os.environ["AZURE_OPENAI_RERANK_DEPLOYMENT_NAME"]
# Create AOAI client for reranking
aoai_rerank_client = AzureOpenAI(
    azure_deployment=rerank_model_name,
    api_version=aoai_api_version,
    azure_endpoint=aoai_rerank_endpoint,
    api_key=azure_openai_rerank_key
)

# AZURE OPENAI FOR EMBEDDING
aoai_embedding_endpoint = os.environ["AZURE_OPENAI_EMBEDDING_ENDPOINT"]
azure_openai_embedding_key = os.environ["AZURE_OPENAI_EMBEDDING_API_KEY"]
embedding_model_name = os.environ["AZURE_OPENAI_EMBEDDING_NAME_ADA"]
# Create AOAI client for embedding creation (ADA)
aoai_embedding_client = AzureOpenAI(
    azure_deployment=embedding_model_name,
    api_version=aoai_api_version,
    azure_endpoint=aoai_embedding_endpoint,
    api_key=azure_openai_embedding_key
)

# CONSTANTS
MAX_DOCS = 20 # Maximum number of documents to retrieve in the query
EMBEDDING_FIELDS = "embeddingTitle, embeddingContent" # Vector fields to search for
SELECT_FIELDS=["id", "title", "content"] # Fields to retrieve in the search
QUERY_LANGUAGE="es-es" # Query language

# %%
import pandas as pd

def show_results(results, query, rerank=False):
    #print(f'query: {query}, num results: {results.get_count()}')
    data = []
    for i, result in enumerate(results):
        if rerank:
            confidence, answer = calculate_rank(aoai_rerank_client, rerank_model_name, result['title'] + ". " + result['content'], query)
            response = f'confidence: {confidence}, answer: {answer}'
        else:
            response = 'n/a'

        data.append(
            [result["id"],
             result["title"],
             result["content"], 
             result["@search.score"],
             response
            ]
        )
        if i + 1 == MAX_DOCS: break # Stops at the maximum number of documents

    return pd.DataFrame(data, columns=["id", "title", "content", "@search.score", "rerank"])

# %%
query = "¿CÓMO DESISTIR DEL RELOJ TECUIDA?"
results = semantic_hybrid_search_with_filter(ai_search_client, query, aoai_embedding_client, embedding_model_name, EMBEDDING_FIELDS, MAX_DOCS, SELECT_FIELDS, QUERY_LANGUAGE)
show_results(results, query, True)
# Out:
#          id                                              title  \
# 0     12857  Pasos a seguir al realizar un Cambio de Tarjet...
# 1    128577  Pasos a seguir al realizar un Cambio de Tarjet...
# 2    132218  Tramitación en ATOS Migracion Activa Contrato ...
# 3     13221  Tramitación en ATOS Migracion Activa Contrato ...
# 4     11909                   Tabla Resumen de Errores (Móvil)
# 5    119096                   Tabla Resumen de Errores (Móvil)
# 6    109934                Locucion Baja Definitiva Contención
# 7     10993                Locucion Baja Definitiva Contención
# 8    104491                    Informacion sobre Datos (Móvil)
# 9     10449                    Informacion sobre Datos (Móvil)
# 10    15997            Codificación activación Duo (Autónomos)
# 11   159979            Codificación activación Duo (Autónomos)
# 12   105853                                            E_Mails
# 13    10585                                            E_Mails
# 14  1602110                  Codificación Multisim (Autónomos)
# 15    16021                  Codificación Multisim (Autónomos)
# 16    11497  Mensajeria Plural/ Directa Terminales Compatib...
# 17   114975  Mensajeria Plural/ Directa Terminales Compatib...
# 18   105052                                            Eventos
#
#                                               content  @search.score  \
# 0   Esta llamada se codifica:\n===\n\n|||\n| - | -...       0.046183
# 1   Esta llamada se codifica:\n===\n\n|||\n| - | -...       0.045453
# 2   Descripción\n===\n\n||\n| - |\n| Tramitación e...       0.043748
# 3   Descripción\n===\n\n||\n| - |\n| Tramitación e...       0.043125
# 4   \n||||\n| - | - | - |\n| ERROR EN: | MENSAJE D...       0.045805
# 5   \n||||\n| - | - | - |\n| ERROR EN: | MENSAJE D...       0.044370
# 6   Descripción\n===\n\n||\n| - |\n| Para transfer...       0.046784
# 7   Descripción\n===\n\n||\n| - |\n| Para transfer...       0.045667
# 8   ?Qué es enviar/recibir Datos\n===\n\n?Qué es e...       0.045517
# 9   ?Qué es enviar/recibir Datos\n===\n\n?Qué es e...       0.044312
# 10  Esta llamada se codifica:\n===\n\nTramitación ...       0.041603
# 11  Esta llamada se codifica:\n===\n\nTramitación ...       0.039730
# 12  Descripción\n===\n\n||\n| - |\n| Debemos envia...       0.041486
# 13  Descripción\n===\n\n||\n| - |\n| Debemos envia...       0.040917
# 14  Esta llamada se codifica:\n===\n\nRuta :\n\nGe...       0.027619
# 15  Esta llamada se codifica:\n===\n\nRuta :\n\nGe...       0.027598
# 16  FABRICANTES\n===\n\n|||\n| - | - |\n| FABRICAN...       0.027047
# 17  FABRICANTES\n===\n\n|||\n| - | - |\n| FABRICAN...       0.026686
# 18  Plantillas\n===\n\n||\n| - |\n| Patrocinio de ...       0.047502
#
#                                                rerank
# 0   confidence: 10, answer: "No se encontró inform...
# 1   confidence: 10, answer: "No se encontró inform...
# 2                           confidence: 0, answer: ""
# 3                           confidence: 0, answer: ""
# 4                           confidence: 0, answer: ""
# 5                           confidence: 0, answer: ""
# 6   confidence: 50, answer: "Para tramitar la baja...
# 7   confidence: 50, answer: "Para tramitar la baja...
# 8                           confidence: 0, answer: ""
# 9                           confidence: 0, answer: ""
# 10                            confidence: 0, answer:
# 11                            confidence: 0, answer:
# 12  confidence: 50, answer: "No hay información re...
# 13  confidence: 50, answer: "No hay información re...
# 14  confidence: 80, answer: "Para desistir del Rel...
# 15  confidence: 80, answer: "Para desistir del Rel...
# 16  confidence: 50, answer: "No information found ...
# 17  confidence: 50, answer: "No information found ...
# 18                          confidence: 0, answer: ""

# %%
query = "Patrocinio de Eventos"
results = semantic_hybrid_search_with_filter(ai_search_client, query, aoai_embedding_client, embedding_model_name, EMBEDDING_FIELDS, MAX_DOCS, SELECT_FIELDS, QUERY_LANGUAGE)
chunks = get_filtered_chunks(aoai_rerank_client, rerank_model_name, results, query, MAX_DOCS)
if len(chunks) > 0:
    # Generate answer using the complete chunks
    answer = generate_answer(aoai_answer_client, aoai_answer_model_name, chunks, query, 'content')
else:
    answer = 'There it not content to generate the answer'
print(f'\nANSWER: {answer}')
# Out:
# chunk: [Eventos. Plantillas
# ===
#
# ||
# | - |
# | Patrocinio de Eventos Ante llamadas de clientes que indiquen estar interesados en que Telefónica Móviles patrocine un evento que su empresa esta preparando, indicar que deben enviar por correo un dossier completo con todos los datos a: Att Francisco García del Pozo o Rocío Vallejo-Nagera Telefónica Móviles España Distrito C, Edificio Sur 1, Planta 4 C/ Ronda de la Comunicación s/n 28050 Madrid |
# | |
# ]
# chunk: [Eventos. Plantillas
# ===
#
# ||
# | - |
# | Patrocinio de Eventos Ante llamadas de clientes que indiquen estar interesados en que Telefónica Móviles patrocine un evento que su empresa esta preparando, indicar que deben enviar por correo un dossier completo con todos los datos a: Att Francisco García del Pozo o Rocío Vallejo-Nagera Telefónica Móviles España Distrito C, Edificio Sur 1, Planta 4 C/ Ronda de la Comunicación s/n 28050 Madrid |
# | |
# ]
# chunk: [Codificación Multisim (Autónomos). Esta llamada se codifica:
# ===
#
# Ruta :
#
# Generar Gestión - Tramitación - Servicios - Línea Múltiple - Multisim - Alta/Baja
#
# Se debe seleccionar la ínea que se va a modificar y se habilitará el botón "Modificar" Al acceder a la pantalla de modificación se debe seleccionar como "Tipo de Actuación": BAJA y "Aceptar"
# ]
# chunk: [Codificación Multisim (Autónomos). Esta llamada se codifica:
# ===
#
# Ruta :
#
# Generar Gestión - Tramitación - Servicios - Línea Múltiple - Multisim - Alta/Baja
#
# Se debe seleccionar la ínea que se va a modificar y se habilitará el botón "Modificar" Al acceder a la pantalla de modificación se debe seleccionar como "Tipo de Actuación": BAJA y "Aceptar"
# ]
# chunk: [Tramitación en ATOS Migracion Activa Contrato (Móvil). Descripción
# ===
#
# ||
# | - |
# | Tramitación en ATOS Migración Activa Contrato |
# | Si el cliente tiene el servicio RAU/RETEL, dar de baja e informar: 1 - Aunque durante el proceso de migración en ATOS, en la pantalla "DATOS MARKETING", el único campo obligatorio es "Uso del teléfono", deberemos procurar rellenar en su totalidad esta pantalla, sobre todo son especialmente importantes los campos "Sexo", y "Fecha de Nacimiento" 2 - Si en algún momento del trámite la persona que llama nos indicara que es menor de edad, se le indicará que no es posible realizar el trámite y se le sugerirá que lo solicite una persona mayor de edad 3 - Cuando se tramite una migración y esta vaya a nombre de una empresa con CIF, se debe indicar la persona que solicita la migración y su NIF en la pantalla de DATOS COMERCIALES/PERSONA AUTORIZADA 4 - Siempre que al tramitar una migración Atos de el error: "OPERACIÓN NO AUTORIZADA" comprobar si se trata de una línea del Segmento Distribuidor, una GGCC o solicitó pago por ventanilla; en estos casos NO TRAMITAR y remitir a Distribuidor Tramitar en la aplicación: Generar contacto: - Movimientos línea / Migración / Activa a Contrato - Cuando se introduce el nif, el campo IAE (actualmente modelo de Declaración Censal de comienzo de actividad) se rellena automáticamente con un SI Por tanto hay que preguntarle al cliente si ese dato es correcto o no para proceder a su modificación - En la pantalla de alta de Cuenta de Facturación, opción "Datos Generales", la opción Paso al Cobro debe tramitarse como "SIEMPRE" Informar al cliente de que su petición ya está tramitada, y que en breve recibirá un mensaje de confirmación dándole la bienvenida a Ms Plus Gestionando la migración se pueden presentar dos tipologías de Incidencias: INCIDENCIAS INFORMÁTICAS Casuística Soluciones Caída de la aplicación Atos El operador seguirá la operativa establecida para los casos de Incidencias en las Aplicaciones Pincha Aquí INCIDENCIAS ADMINISTRATIVAS Y DE SISTEMA Casuística Soluciones Si la aplicación nos da un mensaje de error conforme el cliente tiene deuda ("Operación No Autorizada Llamar UGC") Informar al cliente según proceda y no tramitar la migración Si el cliente manifiesta que no le corresponde pagar la deuda Acudir a los procedimientos de Alta mal tramitada, duplicada, Uso Indebido o baja tardía dependiendo del caso y Consultar/Transferir con coordinador Si la aplicación nos da un mensaje de error conforme el Nif/Cif estuviese en tablas de Dudoso Pago de Sirio Proveedor ("Operación No Autorizada Llamar UGC") Contactar con coordinador para la consulta y con Tráfico para la exclusión en caso de no haber ningún motivo que ratifique que no se pueda tramitar la solicitud del cliente Si la aplicación nos da un mensaje de error conforme el Nif/Cif estuviese en tablas de Morosos de Sico ("Operación No Autorizada Llamar UGC") Contactar con coordinador Si la aplicación nos da un mensaje de error conforme la operación es considerada de Alto Riesgo para TME por parte del departamento de Tráfico ("No se ha podido insertar el abono - No se ha podido realizar la migración") Consultar con el departamento de Tráfico Si la aplicación nos da un mensaje de error conforme el Nif/Cif está duplicado Remitir al cliente al distribuidor para tramitar alta migración Si la aplicación nos da un mensaje de error conforme el Nif/Cif no existe ("No se han podido recuperar los datos del cliente Nif incorrecto ") Confirmar con el cliente NIF/CIF Si persiste, transferir con el coordinador, para que éste si persiste, pida fax con fotocopia NIF/CIF y tramite aplicación Si la aplicación nos da un mensaje de error conforme los datos: calles, bancos, apartados de correos no existen o son incorrectos Transferir a coordinador quien recopilará todos los datos del cliente necesarios para hacer la migración y procederá según las siguientes operativas: - Apertura de Sucursales, Pincha aquí para ver procedimiento (Una vez resuelta la incidencia tramitará la migración y llamará al cliente para informar) Migraciones enganchadas o con errores al finali ...
# ]
# chunk: [Tramitación en ATOS Migracion Activa Contrato (Móvil). Descripción
# ===
#
# ||
# | - |
# | Tramitación en ATOS Migración Activa Contrato |
# | Si el cliente tiene el servicio RAU/RETEL, dar de baja e informar: 1 - Aunque durante el proceso de migración en ATOS, en la pantalla "DATOS MARKETING", el único campo obligatorio es "Uso del teléfono", deberemos procurar rellenar en su totalidad esta pantalla, sobre todo son especialmente importantes los campos "Sexo", y "Fecha de Nacimiento" 2 - Si en algún momento del trámite la persona que llama nos indicara que es menor de edad, se le indicará que no es posible realizar el trámite y se le sugerirá que lo solicite una persona mayor de edad 3 - Cuando se tramite una migración y esta vaya a nombre de una empresa con CIF, se debe indicar la persona que solicita la migración y su NIF en la pantalla de DATOS COMERCIALES/PERSONA AUTORIZADA 4 - Siempre que al tramitar una migración Atos de el error: "OPERACIÓN NO AUTORIZADA" comprobar si se trata de una línea del Segmento Distribuidor, una GGCC o solicitó pago por ventanilla; en estos casos NO TRAMITAR y remitir a Distribuidor Tramitar en la aplicación: Generar contacto: - Movimientos línea / Migración / Activa a Contrato - Cuando se introduce el nif, el campo IAE (actualmente modelo de Declaración Censal de comienzo de actividad) se rellena automáticamente con un SI Por tanto hay que preguntarle al cliente si ese dato es correcto o no para proceder a su modificación - En la pantalla de alta de Cuenta de Facturación, opción "Datos Generales", la opción Paso al Cobro debe tramitarse como "SIEMPRE" Informar al cliente de que su petición ya está tramitada, y que en breve recibirá un mensaje de confirmación dándole la bienvenida a Ms Plus Gestionando la migración se pueden presentar dos tipologías de Incidencias: INCIDENCIAS INFORMÁTICAS Casuística Soluciones Caída de la aplicación Atos El operador seguirá la operativa establecida para los casos de Incidencias en las Aplicaciones Pincha Aquí INCIDENCIAS ADMINISTRATIVAS Y DE SISTEMA Casuística Soluciones Si la aplicación nos da un mensaje de error conforme el cliente tiene deuda ("Operación No Autorizada Llamar UGC") Informar al cliente según proceda y no tramitar la migración Si el cliente manifiesta que no le corresponde pagar la deuda Acudir a los procedimientos de Alta mal tramitada, duplicada, Uso Indebido o baja tardía dependiendo del caso y Consultar/Transferir con coordinador Si la aplicación nos da un mensaje de error conforme el Nif/Cif estuviese en tablas de Dudoso Pago de Sirio Proveedor ("Operación No Autorizada Llamar UGC") Contactar con coordinador para la consulta y con Tráfico para la exclusión en caso de no haber ningún motivo que ratifique que no se pueda tramitar la solicitud del cliente Si la aplicación nos da un mensaje de error conforme el Nif/Cif estuviese en tablas de Morosos de Sico ("Operación No Autorizada Llamar UGC") Contactar con coordinador Si la aplicación nos da un mensaje de error conforme la operación es considerada de Alto Riesgo para TME por parte del departamento de Tráfico ("No se ha podido insertar el abono - No se ha podido realizar la migración") Consultar con el departamento de Tráfico Si la aplicación nos da un mensaje de error conforme el Nif/Cif está duplicado Remitir al cliente al distribuidor para tramitar alta migración Si la aplicación nos da un mensaje de error conforme el Nif/Cif no existe ("No se han podido recuperar los datos del cliente Nif incorrecto ") Confirmar con el cliente NIF/CIF Si persiste, transferir con el coordinador, para que éste si persiste, pida fax con fotocopia NIF/CIF y tramite aplicación Si la aplicación nos da un mensaje de error conforme los datos: calles, bancos, apartados de correos no existen o son incorrectos Transferir a coordinador quien recopilará todos los datos del cliente necesarios para hacer la migración y procederá según las siguientes operativas: - Apertura de Sucursales, Pincha aquí para ver procedimiento (Una vez resuelta la incidencia tramitará la migración y llamará al cliente para informar) Migraciones enganchadas o con errores al finali ...
# ]
# chunk: [Locucion Baja Definitiva Contención. Descripción
# ===
#
# ||
# | - |
# | Para transferir la llamada a la Locución de Baja Definitiva, se debe transferir desde CTC a los siguientes literales: Para clientes NIF à Bajas Móvil Locución NIF Para clientes CIF à Bajas Móvil Locución CIF En caso de contingencia, para transferir desde el Call-Master la llamada se tienen que utilizar los siguientes códigos de transferencia: Para clientes NIF à Código 19 Para clientes CIF à Código 18 La Locución informará a los clientes de la dirección de envío de la carta y de los datos a incluir en la misma Dirección de la CARTA - Para tramitar la baja tiene que enviarnos una carta a la siguiente dirección: Movistar, Aptdo Correos 151 124 28080 Madrid - Una vez recibida la carta, y a la mayor brevedad posible, cursaremos su petición DATOS a enviar en la carta: N I F C I F - Número a dar de baja - Fotocopia de su DNI por las dos caras - Breve escrito solicitando la baja - Su firma - Número a dar de baja - Fotocopia del CIF de la empresa - Fotocopia de su DNI por las dos caras - Breve escrito solicitando la baja - Su firma |
# | |
# ]
# chunk: [Locucion Baja Definitiva Contención. Descripción
# ===
#
# ||
# | - |
# | Para transferir la llamada a la Locución de Baja Definitiva, se debe transferir desde CTC a los siguientes literales: Para clientes NIF à Bajas Móvil Locución NIF Para clientes CIF à Bajas Móvil Locución CIF En caso de contingencia, para transferir desde el Call-Master la llamada se tienen que utilizar los siguientes códigos de transferencia: Para clientes NIF à Código 19 Para clientes CIF à Código 18 La Locución informará a los clientes de la dirección de envío de la carta y de los datos a incluir en la misma Dirección de la CARTA - Para tramitar la baja tiene que enviarnos una carta a la siguiente dirección: Movistar, Aptdo Correos 151 124 28080 Madrid - Una vez recibida la carta, y a la mayor brevedad posible, cursaremos su petición DATOS a enviar en la carta: N I F C I F - Número a dar de baja - Fotocopia de su DNI por las dos caras - Breve escrito solicitando la baja - Su firma - Número a dar de baja - Fotocopia del CIF de la empresa - Fotocopia de su DNI por las dos caras - Breve escrito solicitando la baja - Su firma |
# | |
# ]
# chunk: [Pasos a seguir al realizar un Cambio de Tarjeta Dual - Autónomos (móvil). Esta llamada se codifica:
# ===
#
# |||
# | - | - |
# | Pincha Aquí para identificar el ICC de la línea de Empresa y Particular ||
# | Cambio por Desvinculación | Al realizar el cambio de tarjeta se debe seleccionar la opción "desvinculación" para que el cambio sólo tenga efectividad en la línea donde se está efectuando el cambio Se puede desvincular la de empresas o la particular siempre y cuando la línea particular no tenga un contrato "plan Dual", si lo tuviera la única forma de desvincularlas sería haciendo un cambio de contrato en la línea particular a Ms PLus |
# | Cambio Múltiple | Cuando afecta a las dos líneas, la particular y la de empresa, (deterioro, robo, extravío ) , el cambio se debe hacer siempre desde la línea de empresa |
# | Cambio que Provoca un Alta del Servicio | El cliente de la línea particular puede solicitar incorporar su línea a una línea de empresas que tenga tarjeta dual (si la tarjeta es DU deben coincidir las zonas de operación) y sin necesidad de que lo autorice la empresa El cambio se debe hacer siempre desde la línea particular |
# | ATOS | Movimientos línea/Tarjetas/ICC/Cambio |
# ]
# chunk: [Pasos a seguir al realizar un Cambio de Tarjeta Dual - Autónomos (móvil). Esta llamada se codifica:
# ===
#
# |||
# | - | - |
# | Pincha Aquí para identificar el ICC de la línea de Empresa y Particular ||
# | Cambio por Desvinculación | Al realizar el cambio de tarjeta se debe seleccionar la opción "desvinculación" para que el cambio sólo tenga efectividad en la línea donde se está efectuando el cambio Se puede desvincular la de empresas o la particular siempre y cuando la línea particular no tenga un contrato "plan Dual", si lo tuviera la única forma de desvincularlas sería haciendo un cambio de contrato en la línea particular a Ms PLus |
# | Cambio Múltiple | Cuando afecta a las dos líneas, la particular y la de empresa, (deterioro, robo, extravío ) , el cambio se debe hacer siempre desde la línea de empresa |
# | Cambio que Provoca un Alta del Servicio | El cliente de la línea particular puede solicitar incorporar su línea a una línea de empresas que tenga tarjeta dual (si la tarjeta es DU deben coincidir las zonas de operación) y sin necesidad de que lo autorice la empresa El cambio se debe hacer siempre desde la línea particular |
# | ATOS | Movimientos línea/Tarjetas/ICC/Cambio |
# ]
# chunk: [Codificación activación Duo (Autónomos). Esta llamada se codifica:
# ===
#
# Tramitación / Servicios / Línea Múltiple / Dúo / Alta
#
# Tramitación / Servicios / Línea Múltiple / Dúo / Baja
#
# Seleccionar tipo de Servicio Dúo
#
# En el caso del Alta se deberá introducir el tfno asociado
# ]
# chunk: [Codificación activación Duo (Autónomos). Esta llamada se codifica:
# ===
#
# Tramitación / Servicios / Línea Múltiple / Dúo / Alta
#
# Tramitación / Servicios / Línea Múltiple / Dúo / Baja
#
# Seleccionar tipo de Servicio Dúo
#
# En el caso del Alta se deberá introducir el tfno asociado
# ]
# chunk: [Informacion sobre Datos (Móvil). ?Qué es enviar/recibir Datos
# ===
#
# ?Qué es enviar/recibir Datos?
#
# Todos los clientes pueden enviar/recibir datos a cualquier destino Nacional o Internacional, desde el momento en el que dan de alta su línea Movistar, es decir, navegar por Internet, conectarse a Intranet, consultar/responder correo electrónico?
#
# Se puede enviar y recibir Datos en el propio móvil, en un teléfono MS conectado a un PC/portátil/PDA ó en una PDA si lleva incorporada una tarjeta SIM
#
# ?Necesito una línea exclusiva para enviar/recibir Datos?
#
# Depende del uso que el cliente haga:
#
# ? UNA LÍNEA SÓLO PARA DATOS Cliente que necesita estar constantemente conectado a Internet (p ej un agente de bolsa que trabaja en movilidad, un comercial que hace los pedidos contra el stock del almacén?)
#
# En este caso le interesa el contrato Plus Datos / Plus Datos UMTS, opcionalmente para este último podrá contratar el Módulo C o la Tarifa plana datos
#
# ? UNA SÓLA LÍNEA PARA VOZ y DATOS Si sólo se conecta a Internet puntualmente, o utiliza e-moción, con su línea de voz será suficiente, es recomendable contratar un módulo de datos para que le cueste más barato el tráfico de datos
#
# GSM, GPRS, UMTS
#
# GSM, GPRS y UMTS son tecnologías, sistemas de telefonía móvil digital
#
# ? GSM fue la primera en lanzarse El tráfico de datos lo factura por tiempo de conexión
#
# ? GPRS y UMTS tecnologías que complementan con GSM y que mejoran los servicios de transmisión y recepción de datos El tráfico de datos se factura por volumen de información transmitida (paquetes de información)
#
# Tipos de accesos: ?Wap? y ?Internet/Intranet?
#
# Con nuestro móvil podemos utilizar dos tipos de acceso distintos:
#
# ? Wap es una tecnología desarrollada para el acceso a información y contenidos desde dispositivos móviles (principalmente teléfonos móviles, aunque también se pueden utilizar otros dispositivos como PDAs) Es decir, siempre que accedemos directamente desde nuestro terminal a e-moción o a páginas desarrolladas con esta tecnología estamos utilizando el acceso Wap
#
# ? Internet - es una red compuesta de páginas Web a la que se accede desde un PC (y desde determinados modelos de terminales o PDA´s ) utilizando un móvil como módem mediante un cable de conexión, puerto de infrarrojos o bluetooth o con una tarjeta PCMCIA Estas conexiones y las que realicemos para la consulta de Correo Electrónico las haremos con acceso Internet/Intranet
#
# ? Intranet - la forma de acceder a Intranet es la misma que a Internet, pero no se aacede a páginas web, sino a los servidores corporativos de la empresa Estas conexiones las haremos con acceso Internet/Intranet
#
# ?Cómo veo todo esto en una factura?
#
# ?Y si el cliente tiene un Módulo de Datos?
#
# Lo puedo ver en la pestaña de Servicios/ Serv Valor Añadido
#
# Tarifa Plana Datos
#
# Mód Datos B
# ]
# chunk: [Informacion sobre Datos (Móvil). ?Qué es enviar/recibir Datos
# ===
#
# ?Qué es enviar/recibir Datos?
#
# Todos los clientes pueden enviar/recibir datos a cualquier destino Nacional o Internacional, desde el momento en el que dan de alta su línea Movistar, es decir, navegar por Internet, conectarse a Intranet, consultar/responder correo electrónico?
#
# Se puede enviar y recibir Datos en el propio móvil, en un teléfono MS conectado a un PC/portátil/PDA ó en una PDA si lleva incorporada una tarjeta SIM
#
# ?Necesito una línea exclusiva para enviar/recibir Datos?
#
# Depende del uso que el cliente haga:
#
# ? UNA LÍNEA SÓLO PARA DATOS Cliente que necesita estar constantemente conectado a Internet (p ej un agente de bolsa que trabaja en movilidad, un comercial que hace los pedidos contra el stock del almacén?)
#
# En este caso le interesa el contrato Plus Datos / Plus Datos UMTS, opcionalmente para este último podrá contratar el Módulo C o la Tarifa plana datos
#
# ? UNA SÓLA LÍNEA PARA VOZ y DATOS Si sólo se conecta a Internet puntualmente, o utiliza e-moción, con su línea de voz será suficiente, es recomendable contratar un módulo de datos para que le cueste más barato el tráfico de datos
#
# GSM, GPRS, UMTS
#
# GSM, GPRS y UMTS son tecnologías, sistemas de telefonía móvil digital
#
# ? GSM fue la primera en lanzarse El tráfico de datos lo factura por tiempo de conexión
#
# ? GPRS y UMTS tecnologías que complementan con GSM y que mejoran los servicios de transmisión y recepción de datos El tráfico de datos se factura por volumen de información transmitida (paquetes de información)
#
# Tipos de accesos: ?Wap? y ?Internet/Intranet?
#
# Con nuestro móvil podemos utilizar dos tipos de acceso distintos:
#
# ? Wap es una tecnología desarrollada para el acceso a información y contenidos desde dispositivos móviles (principalmente teléfonos móviles, aunque también se pueden utilizar otros dispositivos como PDAs) Es decir, siempre que accedemos directamente desde nuestro terminal a e-moción o a páginas desarrolladas con esta tecnología estamos utilizando el acceso Wap
#
# ? Internet - es una red compuesta de páginas Web a la que se accede desde un PC (y desde determinados modelos de terminales o PDA´s ) utilizando un móvil como módem mediante un cable de conexión, puerto de infrarrojos o bluetooth o con una tarjeta PCMCIA Estas conexiones y las que realicemos para la consulta de Correo Electrónico las haremos con acceso Internet/Intranet
#
# ? Intranet - la forma de acceder a Intranet es la misma que a Internet, pero no se aacede a páginas web, sino a los servidores corporativos de la empresa Estas conexiones las haremos con acceso Internet/Intranet
#
# ?Cómo veo todo esto en una factura?
#
# ?Y si el cliente tiene un Módulo de Datos?
#
# Lo puedo ver en la pestaña de Servicios/ Serv Valor Añadido
#
# Tarifa Plana Datos
#
# Mód Datos B
# ]
# chunk: [E_Mails. Descripción
# ===
#
# ||
# | - |
# | Debemos enviar un email a las D T siempre que el cliente solicite la activacion de algun servicio que nosotros no podamos activarlo con las herramientas que tenemos, como un Servicio Integra, Instalacion de un Enlace, etc En estos casos debemos: Indicar el Titular y Cif del cliente Responsable de Número de Atención Personal y Tfno de Contacto Breve descripción de lo que el cliente solicita Si la peticion fuera urgente, lo indicariais en el asunto de email ( URGENTE!!!!!! ) Firma siempre todos los correos con TU NOMBRE Y APELLIDOS Siempre debemos tener una respuesta de la D T , el plazo de respuesta debe ser en 1 dia |
# | |
# ]
# chunk: [E_Mails. Descripción
# ===
#
# ||
# | - |
# | Debemos enviar un email a las D T siempre que el cliente solicite la activacion de algun servicio que nosotros no podamos activarlo con las herramientas que tenemos, como un Servicio Integra, Instalacion de un Enlace, etc En estos casos debemos: Indicar el Titular y Cif del cliente Responsable de Número de Atención Personal y Tfno de Contacto Breve descripción de lo que el cliente solicita Si la peticion fuera urgente, lo indicariais en el asunto de email ( URGENTE!!!!!! ) Firma siempre todos los correos con TU NOMBRE Y APELLIDOS Siempre debemos tener una respuesta de la D T , el plazo de respuesta debe ser en 1 dia |
# | |
# ]
# chunk: [Tabla Resumen de Errores (Móvil).
# ||||
# | - | - | - |
# | ERROR EN: | MENSAJE DE ERROR | SOLUCIÓN |
# | Instalación | Error de seguridad de instanlación Imposible de instalar | En el menú principal debe seleccionar Herramientas>Gestor de aplicaciones>Opciones>Ajustes>Instalación del Software>Opciones>Cambiar Asegurate que está activo |
# | Conexión Bluetooth | La conexión con Bluetooth está ocupada | Asegurarse de que el teléfono móvil y/o eñ receptor GPS no está conectado a otro dispositivo Bluethooth Intentar de nuevo conectar con el receptor GPS correcto |
# || Error de conexión con Bluetooth Error de ejecución de Bluetooth | Comprobar lo siguiente: 1 Si Bluetooth está activado en el teléfono móvil y que el receptor Bluetooth de GPS está encendido 2 Situar el receptor Bluetooth de GPS no más lejos de 10 metros del teléfono móvil 3 Que tu teléfono móvil no está conectado a otro dispositivo Bluetooth 4 Que la opción de reconexión GPS automática está desactivada/off 5 Intentar conectar con el receptor Bluetooth de nuevo |
# || Bluetooth desconectado | Comprobar que el receptor GPS está encendido y no más lejos de 10 metros del teléfono móvil e intentar conectar de nuevo con el receptor GPS Y activar Bluetooth en el teléfono móvil |
# || Error de recepción de Bluetooth | Es debido a que RutaMoviStar no recibe datos del GPS Intentar iniciar la aplicación RutaMoviStar y/o el receptor GPS de nuevo |
# | Receptor GPS | No hay datos GPS | Puede ser debido a la comunicación Bluetooth y/o a la recepción GPS Comprobar: 1 Que el receptor GPS está encendido, la baterúia está cargada y el teléfono m´voil está conectado al receptor Bluetooth del GPS 2 Que la distancia entre el receptor GPS y el teléfno móvil no es superior a 10 m 3 Que el recpetor GPS pueda recibir las señales de los satélites, para ello deberá estar al aire o junto a una ventana 4 - Que el GPS conecta con el satélite En caso contrario, o en caso de no responder, remitir al Distribuidor o al Servicio Técnico del equipo |
# | Respuesta tras la búsqueda | Búsqueda devuelta, ninguna coincidencia | El principal motivo es porque uno de los tres campos necesarios no están rellenados con la información: Dirección/Empresa, Ciudad/código postal, País (en el primer y segundo campo sólo hay que introducir uno de los dos datos que se pide, es decir, o la dirección o la Empresa, o la ciudad o el código postal) También puede ser debido a que la ortografía no es correcta O que el país seleccionado no sea el correcto |
# | Instalación de RutaMoviStar | \*El archivo que contiene sonidos está corrupto \*El archivo que contiene gráficos está corrupto \*Los recursos que dependen del lenguaje para El lenguaje activo no se han instalado correctamente El audio va a ser inhabilitado \*Error de idioma en la instalación El programa finalizará \*La instalación está dañada y el programa se cerrará | 1 Cerrar la aplicación RutaMoviStar 2 En el menú principal del tléfono seleccionar Herramientas>Opciones>Abrir 3 Marcar uno de los ficheros existentes y presionar Opciones>Quitar Es muy importante que borre todos los ficheros actuales 4 Reinstalar RutaMoviStar |
# | GPRS | \*No se ha encontrado el servidor Comprueba tus ajustes de Internet \*Error de red Comprueba tus ajustes de Internet \*Conexión falló, comprueba la red | Puede ser debido a los siguientes motivos: 1 No tiene GPRS activado y/o configurado su terminal Activar este servicio si es así y/o configurar el terminal 2 Problemas en la red GPRS |
# || \*Finalización de tiempo de servidor interno \*El servidor no responde Inténtalo de nuevo \*Se ha roto la comunicación con el servidor Inténtalo de nuevo \*Finalización de tiempo en la comunicación del servidor | Son mensajes de error temporal con duración corta y probablemente habrán terminado si lo intenta de nuevo |
# | Memoria | \*No hay suficiente memoria disponible, el programa se cerrará \*No queda más espacio en el dispositivo Cerrando el programa | Eliminar datos de la memoria del terminal para incrementar su capacidad y poder realizar la acción solicitada |
# | Favoritos (web) | Sincronización de Favoritos en progreso | Esperar hasta que haya finalizado la sincronización |
# || Favoritos están corruptos | Sleccionar Sincronizar para actualizar la información disopnible sobre tus Favoritos |
# | Otros | No hay destino a la ruta hacia | No se ha establecido un destino y por lo tanto RutaMoviStar no puede calcular la ruta Se ha de definir el destino |
# || Origen no establecido | Se está calculando una ruta sin estar conectado al receptor GPS y por lo tanto hay que definir el origen y el destino |
# || Ruta demasiado larga para el tipo de vehículo | Probablemente tenga seleccionado como tipo de vehículo "peatón" y la ruta es demasiado larga (más de 10 kms) Se deberá cambiar a Automóvil o a Taxi |
# ]
# chunk: [Tabla Resumen de Errores (Móvil).
# ||||
# | - | - | - |
# | ERROR EN: | MENSAJE DE ERROR | SOLUCIÓN |
# | Instalación | Error de seguridad de instanlación Imposible de instalar | En el menú principal debe seleccionar Herramientas>Gestor de aplicaciones>Opciones>Ajustes>Instalación del Software>Opciones>Cambiar Asegurate que está activo |
# | Conexión Bluetooth | La conexión con Bluetooth está ocupada | Asegurarse de que el teléfono móvil y/o eñ receptor GPS no está conectado a otro dispositivo Bluethooth Intentar de nuevo conectar con el receptor GPS correcto |
# || Error de conexión con Bluetooth Error de ejecución de Bluetooth | Comprobar lo siguiente: 1 Si Bluetooth está activado en el teléfono móvil y que el receptor Bluetooth de GPS está encendido 2 Situar el receptor Bluetooth de GPS no más lejos de 10 metros del teléfono móvil 3 Que tu teléfono móvil no está conectado a otro dispositivo Bluetooth 4 Que la opción de reconexión GPS automática está desactivada/off 5 Intentar conectar con el receptor Bluetooth de nuevo |
# || Bluetooth desconectado | Comprobar que el receptor GPS está encendido y no más lejos de 10 metros del teléfono móvil e intentar conectar de nuevo con el receptor GPS Y activar Bluetooth en el teléfono móvil |
# || Error de recepción de Bluetooth | Es debido a que RutaMoviStar no recibe datos del GPS Intentar iniciar la aplicación RutaMoviStar y/o el receptor GPS de nuevo |
# | Receptor GPS | No hay datos GPS | Puede ser debido a la comunicación Bluetooth y/o a la recepción GPS Comprobar: 1 Que el receptor GPS está encendido, la baterúia está cargada y el teléfono m´voil está conectado al receptor Bluetooth del GPS 2 Que la distancia entre el receptor GPS y el teléfno móvil no es superior a 10 m 3 Que el recpetor GPS pueda recibir las señales de los satélites, para ello deberá estar al aire o junto a una ventana 4 - Que el GPS conecta con el satélite En caso contrario, o en caso de no responder, remitir al Distribuidor o al Servicio Técnico del equipo |
# | Respuesta tras la búsqueda | Búsqueda devuelta, ninguna coincidencia | El principal motivo es porque uno de los tres campos necesarios no están rellenados con la información: Dirección/Empresa, Ciudad/código postal, País (en el primer y segundo campo sólo hay que introducir uno de los dos datos que se pide, es decir, o la dirección o la Empresa, o la ciudad o el código postal) También puede ser debido a que la ortografía no es correcta O que el país seleccionado no sea el correcto |
# | Instalación de RutaMoviStar | \*El archivo que contiene sonidos está corrupto \*El archivo que contiene gráficos está corrupto \*Los recursos que dependen del lenguaje para El lenguaje activo no se han instalado correctamente El audio va a ser inhabilitado \*Error de idioma en la instalación El programa finalizará \*La instalación está dañada y el programa se cerrará | 1 Cerrar la aplicación RutaMoviStar 2 En el menú principal del tléfono seleccionar Herramientas>Opciones>Abrir 3 Marcar uno de los ficheros existentes y presionar Opciones>Quitar Es muy importante que borre todos los ficheros actuales 4 Reinstalar RutaMoviStar |
# | GPRS | \*No se ha encontrado el servidor Comprueba tus ajustes de Internet \*Error de red Comprueba tus ajustes de Internet \*Conexión falló, comprueba la red | Puede ser debido a los siguientes motivos: 1 No tiene GPRS activado y/o configurado su terminal Activar este servicio si es así y/o configurar el terminal 2 Problemas en la red GPRS |
# || \*Finalización de tiempo de servidor interno \*El servidor no responde Inténtalo de nuevo \*Se ha roto la comunicación con el servidor Inténtalo de nuevo \*Finalización de tiempo en la comunicación del servidor | Son mensajes de error temporal con duración corta y probablemente habrán terminado si lo intenta de nuevo |
# | Memoria | \*No hay suficiente memoria disponible, el programa se cerrará \*No queda más espacio en el dispositivo Cerrando el programa | Eliminar datos de la memoria del terminal para incrementar su capacidad y poder realizar la acción solicitada |
# | Favoritos (web) | Sincronización de Favoritos en progreso | Esperar hasta que haya finalizado la sincronización |
# || Favoritos están corruptos | Sleccionar Sincronizar para actualizar la información disopnible sobre tus Favoritos |
# | Otros | No hay destino a la ruta hacia | No se ha establecido un destino y por lo tanto RutaMoviStar no puede calcular la ruta Se ha de definir el destino |
# || Origen no establecido | Se está calculando una ruta sin estar conectado al receptor GPS y por lo tanto hay que definir el origen y el destino |
# || Ruta demasiado larga para el tipo de vehículo | Probablemente tenga seleccionado como tipo de vehículo "peatón" y la ruta es demasiado larga (más de 10 kms) Se deberá cambiar a Automóvil o a Taxi |
# ]
# chunk: [Mensajeria Plural/ Directa Terminales Compatibles (Móvil). FABRICANTES
# ===
#
# |||
# | - | - |
# | FABRICANTES | MODELOS |
# | ALCATEL | ONE TOUCH 535,ONE TOUCH 715,ONE TOUCH 735,ONE TOUCH POCKET, 735 i |
# | LG | G510, G7200 |
# | MOTOROLA | LSERIES,SMART CELLECT,STARTAC130, C350 - C333 - V70 y V66 i |
# | NEC | N331 i |
# | NOKIA | 5110,6100,6110,6150,6210,6310I,6510,7110,8310,CELLULAR DATA ADAPTER FOR GSM AND PCN/DCS 1800 (PREMICELL),CELLULAR DATA SUITE 3 0, 6310 - 6310 i - 7210 i |
# | PHIILIPS | 535 |
# | NOVATEL | Merlin U530 |
# | SAGEM | MYX3-D,MYX-6 |
# | SAMSUNG | V200 |
# | SIEMENS | C35I,C45,C55,M1,M20,M55,MC35,ME45,S35,S45,S55, SL 45 |
# | SIERRA WIRELESS | AIRCARD? 750 WIRELESS NETWORK CARD,WIRELESS AIRCARD 750 |
# | SONY-ERICSSON | T300, T68 i |
# | WAVECOM | GSM MÃ“DEM WM01-6906 (WISMO),WM1080A MULTIBAND 900E 1800,WMO2 900P,WMOD2 MULTIBAND 900E 1800,WMOD240 MULTIBAND 900E 1800 |
# ]
# chunk: [Mensajeria Plural/ Directa Terminales Compatibles (Móvil). FABRICANTES
# ===
#
# |||
# | - | - |
# | FABRICANTES | MODELOS |
# | ALCATEL | ONE TOUCH 535,ONE TOUCH 715,ONE TOUCH 735,ONE TOUCH POCKET, 735 i |
# | LG | G510, G7200 |
# | MOTOROLA | LSERIES,SMART CELLECT,STARTAC130, C350 - C333 - V70 y V66 i |
# | NEC | N331 i |
# | NOKIA | 5110,6100,6110,6150,6210,6310I,6510,7110,8310,CELLULAR DATA ADAPTER FOR GSM AND PCN/DCS 1800 (PREMICELL),CELLULAR DATA SUITE 3 0, 6310 - 6310 i - 7210 i |
# | PHIILIPS | 535 |
# | NOVATEL | Merlin U530 |
# | SAGEM | MYX3-D,MYX-6 |
# | SAMSUNG | V200 |
# | SIEMENS | C35I,C45,C55,M1,M20,M55,MC35,ME45,S35,S45,S55, SL 45 |
# | SIERRA WIRELESS | AIRCARD? 750 WIRELESS NETWORK CARD,WIRELESS AIRCARD 750 |
# | SONY-ERICSSON | T300, T68 i |
# | WAVECOM | GSM MÃ“DEM WM01-6906 (WISMO),WM1080A MULTIBAND 900E 1800,WMO2 900P,WMOD2 MULTIBAND 900E 1800,WMOD240 MULTIBAND 900E 1800 |
# ]
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 100,
# 	answer: "Para solicitar el patrocinio de un evento por parte de Telefónica Móviles, los clientes interesados deben enviar un dossier completo con todos los datos por correo a Francisco García del Pozo o Rocío Vallejo-Nagera en la dirección: Distrito C, Edificio Sur 1, Planta 4 C/ Ronda de la Comunicación s/n 28050 Madrid."
#
# ANSWER: No tengo suficiente información para responder a la pregunta, quizás si la reformulas, podré encontrar la respuesta.

# %%
query = "Patrocinio de Eventos"
results = semantic_hybrid_search_with_filter(ai_search_client, query, aoai_embedding_client, embedding_model_name, EMBEDDING_FIELDS, MAX_DOCS, SELECT_FIELDS, QUERY_LANGUAGE)
chunks = get_filtered_chunks(aoai_rerank_client, rerank_model_name, results, query, MAX_DOCS)
if len(chunks) > 0:
    # Generate answer using the 'answer' generated by the re-ranker
    answer = generate_answer(aoai_answer_client, aoai_answer_model_name, chunks, query, 'answer')
else:
    answer = 'There it not content to generate the answer'
print(f'\nANSWER: {answer}')
# Out:
# chunk: [Eventos. Plantillas
# ===
#
# ||
# | - |
# | Patrocinio de Eventos Ante llamadas de clientes que indiquen estar interesados en que Telefónica Móviles patrocine un evento que su empresa esta preparando, indicar que deben enviar por correo un dossier completo con todos los datos a: Att Francisco García del Pozo o Rocío Vallejo-Nagera Telefónica Móviles España Distrito C, Edificio Sur 1, Planta 4 C/ Ronda de la Comunicación s/n 28050 Madrid |
# | |
# ]
# chunk: [Eventos. Plantillas
# ===
#
# ||
# | - |
# | Patrocinio de Eventos Ante llamadas de clientes que indiquen estar interesados en que Telefónica Móviles patrocine un evento que su empresa esta preparando, indicar que deben enviar por correo un dossier completo con todos los datos a: Att Francisco García del Pozo o Rocío Vallejo-Nagera Telefónica Móviles España Distrito C, Edificio Sur 1, Planta 4 C/ Ronda de la Comunicación s/n 28050 Madrid |
# | |
# ]
# chunk: [Codificación Multisim (Autónomos). Esta llamada se codifica:
# ===
#
# Ruta :
#
# Generar Gestión - Tramitación - Servicios - Línea Múltiple - Multisim - Alta/Baja
#
# Se debe seleccionar la ínea que se va a modificar y se habilitará el botón "Modificar" Al acceder a la pantalla de modificación se debe seleccionar como "Tipo de Actuación": BAJA y "Aceptar"
# ]
# chunk: [Codificación Multisim (Autónomos). Esta llamada se codifica:
# ===
#
# Ruta :
#
# Generar Gestión - Tramitación - Servicios - Línea Múltiple - Multisim - Alta/Baja
#
# Se debe seleccionar la ínea que se va a modificar y se habilitará el botón "Modificar" Al acceder a la pantalla de modificación se debe seleccionar como "Tipo de Actuación": BAJA y "Aceptar"
# ]
# chunk: [Tramitación en ATOS Migracion Activa Contrato (Móvil). Descripción
# ===
#
# ||
# | - |
# | Tramitación en ATOS Migración Activa Contrato |
# | Si el cliente tiene el servicio RAU/RETEL, dar de baja e informar: 1 - Aunque durante el proceso de migración en ATOS, en la pantalla "DATOS MARKETING", el único campo obligatorio es "Uso del teléfono", deberemos procurar rellenar en su totalidad esta pantalla, sobre todo son especialmente importantes los campos "Sexo", y "Fecha de Nacimiento" 2 - Si en algún momento del trámite la persona que llama nos indicara que es menor de edad, se le indicará que no es posible realizar el trámite y se le sugerirá que lo solicite una persona mayor de edad 3 - Cuando se tramite una migración y esta vaya a nombre de una empresa con CIF, se debe indicar la persona que solicita la migración y su NIF en la pantalla de DATOS COMERCIALES/PERSONA AUTORIZADA 4 - Siempre que al tramitar una migración Atos de el error: "OPERACIÓN NO AUTORIZADA" comprobar si se trata de una línea del Segmento Distribuidor, una GGCC o solicitó pago por ventanilla; en estos casos NO TRAMITAR y remitir a Distribuidor Tramitar en la aplicación: Generar contacto: - Movimientos línea / Migración / Activa a Contrato - Cuando se introduce el nif, el campo IAE (actualmente modelo de Declaración Censal de comienzo de actividad) se rellena automáticamente con un SI Por tanto hay que preguntarle al cliente si ese dato es correcto o no para proceder a su modificación - En la pantalla de alta de Cuenta de Facturación, opción "Datos Generales", la opción Paso al Cobro debe tramitarse como "SIEMPRE" Informar al cliente de que su petición ya está tramitada, y que en breve recibirá un mensaje de confirmación dándole la bienvenida a Ms Plus Gestionando la migración se pueden presentar dos tipologías de Incidencias: INCIDENCIAS INFORMÁTICAS Casuística Soluciones Caída de la aplicación Atos El operador seguirá la operativa establecida para los casos de Incidencias en las Aplicaciones Pincha Aquí INCIDENCIAS ADMINISTRATIVAS Y DE SISTEMA Casuística Soluciones Si la aplicación nos da un mensaje de error conforme el cliente tiene deuda ("Operación No Autorizada Llamar UGC") Informar al cliente según proceda y no tramitar la migración Si el cliente manifiesta que no le corresponde pagar la deuda Acudir a los procedimientos de Alta mal tramitada, duplicada, Uso Indebido o baja tardía dependiendo del caso y Consultar/Transferir con coordinador Si la aplicación nos da un mensaje de error conforme el Nif/Cif estuviese en tablas de Dudoso Pago de Sirio Proveedor ("Operación No Autorizada Llamar UGC") Contactar con coordinador para la consulta y con Tráfico para la exclusión en caso de no haber ningún motivo que ratifique que no se pueda tramitar la solicitud del cliente Si la aplicación nos da un mensaje de error conforme el Nif/Cif estuviese en tablas de Morosos de Sico ("Operación No Autorizada Llamar UGC") Contactar con coordinador Si la aplicación nos da un mensaje de error conforme la operación es considerada de Alto Riesgo para TME por parte del departamento de Tráfico ("No se ha podido insertar el abono - No se ha podido realizar la migración") Consultar con el departamento de Tráfico Si la aplicación nos da un mensaje de error conforme el Nif/Cif está duplicado Remitir al cliente al distribuidor para tramitar alta migración Si la aplicación nos da un mensaje de error conforme el Nif/Cif no existe ("No se han podido recuperar los datos del cliente Nif incorrecto ") Confirmar con el cliente NIF/CIF Si persiste, transferir con el coordinador, para que éste si persiste, pida fax con fotocopia NIF/CIF y tramite aplicación Si la aplicación nos da un mensaje de error conforme los datos: calles, bancos, apartados de correos no existen o son incorrectos Transferir a coordinador quien recopilará todos los datos del cliente necesarios para hacer la migración y procederá según las siguientes operativas: - Apertura de Sucursales, Pincha aquí para ver procedimiento (Una vez resuelta la incidencia tramitará la migración y llamará al cliente para informar) Migraciones enganchadas o con errores al finali ...
# ]
# chunk: [Tramitación en ATOS Migracion Activa Contrato (Móvil). Descripción
# ===
#
# ||
# | - |
# | Tramitación en ATOS Migración Activa Contrato |
# | Si el cliente tiene el servicio RAU/RETEL, dar de baja e informar: 1 - Aunque durante el proceso de migración en ATOS, en la pantalla "DATOS MARKETING", el único campo obligatorio es "Uso del teléfono", deberemos procurar rellenar en su totalidad esta pantalla, sobre todo son especialmente importantes los campos "Sexo", y "Fecha de Nacimiento" 2 - Si en algún momento del trámite la persona que llama nos indicara que es menor de edad, se le indicará que no es posible realizar el trámite y se le sugerirá que lo solicite una persona mayor de edad 3 - Cuando se tramite una migración y esta vaya a nombre de una empresa con CIF, se debe indicar la persona que solicita la migración y su NIF en la pantalla de DATOS COMERCIALES/PERSONA AUTORIZADA 4 - Siempre que al tramitar una migración Atos de el error: "OPERACIÓN NO AUTORIZADA" comprobar si se trata de una línea del Segmento Distribuidor, una GGCC o solicitó pago por ventanilla; en estos casos NO TRAMITAR y remitir a Distribuidor Tramitar en la aplicación: Generar contacto: - Movimientos línea / Migración / Activa a Contrato - Cuando se introduce el nif, el campo IAE (actualmente modelo de Declaración Censal de comienzo de actividad) se rellena automáticamente con un SI Por tanto hay que preguntarle al cliente si ese dato es correcto o no para proceder a su modificación - En la pantalla de alta de Cuenta de Facturación, opción "Datos Generales", la opción Paso al Cobro debe tramitarse como "SIEMPRE" Informar al cliente de que su petición ya está tramitada, y que en breve recibirá un mensaje de confirmación dándole la bienvenida a Ms Plus Gestionando la migración se pueden presentar dos tipologías de Incidencias: INCIDENCIAS INFORMÁTICAS Casuística Soluciones Caída de la aplicación Atos El operador seguirá la operativa establecida para los casos de Incidencias en las Aplicaciones Pincha Aquí INCIDENCIAS ADMINISTRATIVAS Y DE SISTEMA Casuística Soluciones Si la aplicación nos da un mensaje de error conforme el cliente tiene deuda ("Operación No Autorizada Llamar UGC") Informar al cliente según proceda y no tramitar la migración Si el cliente manifiesta que no le corresponde pagar la deuda Acudir a los procedimientos de Alta mal tramitada, duplicada, Uso Indebido o baja tardía dependiendo del caso y Consultar/Transferir con coordinador Si la aplicación nos da un mensaje de error conforme el Nif/Cif estuviese en tablas de Dudoso Pago de Sirio Proveedor ("Operación No Autorizada Llamar UGC") Contactar con coordinador para la consulta y con Tráfico para la exclusión en caso de no haber ningún motivo que ratifique que no se pueda tramitar la solicitud del cliente Si la aplicación nos da un mensaje de error conforme el Nif/Cif estuviese en tablas de Morosos de Sico ("Operación No Autorizada Llamar UGC") Contactar con coordinador Si la aplicación nos da un mensaje de error conforme la operación es considerada de Alto Riesgo para TME por parte del departamento de Tráfico ("No se ha podido insertar el abono - No se ha podido realizar la migración") Consultar con el departamento de Tráfico Si la aplicación nos da un mensaje de error conforme el Nif/Cif está duplicado Remitir al cliente al distribuidor para tramitar alta migración Si la aplicación nos da un mensaje de error conforme el Nif/Cif no existe ("No se han podido recuperar los datos del cliente Nif incorrecto ") Confirmar con el cliente NIF/CIF Si persiste, transferir con el coordinador, para que éste si persiste, pida fax con fotocopia NIF/CIF y tramite aplicación Si la aplicación nos da un mensaje de error conforme los datos: calles, bancos, apartados de correos no existen o son incorrectos Transferir a coordinador quien recopilará todos los datos del cliente necesarios para hacer la migración y procederá según las siguientes operativas: - Apertura de Sucursales, Pincha aquí para ver procedimiento (Una vez resuelta la incidencia tramitará la migración y llamará al cliente para informar) Migraciones enganchadas o con errores al finali ...
# ]
# chunk: [Locucion Baja Definitiva Contención. Descripción
# ===
#
# ||
# | - |
# | Para transferir la llamada a la Locución de Baja Definitiva, se debe transferir desde CTC a los siguientes literales: Para clientes NIF à Bajas Móvil Locución NIF Para clientes CIF à Bajas Móvil Locución CIF En caso de contingencia, para transferir desde el Call-Master la llamada se tienen que utilizar los siguientes códigos de transferencia: Para clientes NIF à Código 19 Para clientes CIF à Código 18 La Locución informará a los clientes de la dirección de envío de la carta y de los datos a incluir en la misma Dirección de la CARTA - Para tramitar la baja tiene que enviarnos una carta a la siguiente dirección: Movistar, Aptdo Correos 151 124 28080 Madrid - Una vez recibida la carta, y a la mayor brevedad posible, cursaremos su petición DATOS a enviar en la carta: N I F C I F - Número a dar de baja - Fotocopia de su DNI por las dos caras - Breve escrito solicitando la baja - Su firma - Número a dar de baja - Fotocopia del CIF de la empresa - Fotocopia de su DNI por las dos caras - Breve escrito solicitando la baja - Su firma |
# | |
# ]
# chunk: [Locucion Baja Definitiva Contención. Descripción
# ===
#
# ||
# | - |
# | Para transferir la llamada a la Locución de Baja Definitiva, se debe transferir desde CTC a los siguientes literales: Para clientes NIF à Bajas Móvil Locución NIF Para clientes CIF à Bajas Móvil Locución CIF En caso de contingencia, para transferir desde el Call-Master la llamada se tienen que utilizar los siguientes códigos de transferencia: Para clientes NIF à Código 19 Para clientes CIF à Código 18 La Locución informará a los clientes de la dirección de envío de la carta y de los datos a incluir en la misma Dirección de la CARTA - Para tramitar la baja tiene que enviarnos una carta a la siguiente dirección: Movistar, Aptdo Correos 151 124 28080 Madrid - Una vez recibida la carta, y a la mayor brevedad posible, cursaremos su petición DATOS a enviar en la carta: N I F C I F - Número a dar de baja - Fotocopia de su DNI por las dos caras - Breve escrito solicitando la baja - Su firma - Número a dar de baja - Fotocopia del CIF de la empresa - Fotocopia de su DNI por las dos caras - Breve escrito solicitando la baja - Su firma |
# | |
# ]
# chunk: [Pasos a seguir al realizar un Cambio de Tarjeta Dual - Autónomos (móvil). Esta llamada se codifica:
# ===
#
# |||
# | - | - |
# | Pincha Aquí para identificar el ICC de la línea de Empresa y Particular ||
# | Cambio por Desvinculación | Al realizar el cambio de tarjeta se debe seleccionar la opción "desvinculación" para que el cambio sólo tenga efectividad en la línea donde se está efectuando el cambio Se puede desvincular la de empresas o la particular siempre y cuando la línea particular no tenga un contrato "plan Dual", si lo tuviera la única forma de desvincularlas sería haciendo un cambio de contrato en la línea particular a Ms PLus |
# | Cambio Múltiple | Cuando afecta a las dos líneas, la particular y la de empresa, (deterioro, robo, extravío ) , el cambio se debe hacer siempre desde la línea de empresa |
# | Cambio que Provoca un Alta del Servicio | El cliente de la línea particular puede solicitar incorporar su línea a una línea de empresas que tenga tarjeta dual (si la tarjeta es DU deben coincidir las zonas de operación) y sin necesidad de que lo autorice la empresa El cambio se debe hacer siempre desde la línea particular |
# | ATOS | Movimientos línea/Tarjetas/ICC/Cambio |
# ]
# chunk: [Pasos a seguir al realizar un Cambio de Tarjeta Dual - Autónomos (móvil). Esta llamada se codifica:
# ===
#
# |||
# | - | - |
# | Pincha Aquí para identificar el ICC de la línea de Empresa y Particular ||
# | Cambio por Desvinculación | Al realizar el cambio de tarjeta se debe seleccionar la opción "desvinculación" para que el cambio sólo tenga efectividad en la línea donde se está efectuando el cambio Se puede desvincular la de empresas o la particular siempre y cuando la línea particular no tenga un contrato "plan Dual", si lo tuviera la única forma de desvincularlas sería haciendo un cambio de contrato en la línea particular a Ms PLus |
# | Cambio Múltiple | Cuando afecta a las dos líneas, la particular y la de empresa, (deterioro, robo, extravío ) , el cambio se debe hacer siempre desde la línea de empresa |
# | Cambio que Provoca un Alta del Servicio | El cliente de la línea particular puede solicitar incorporar su línea a una línea de empresas que tenga tarjeta dual (si la tarjeta es DU deben coincidir las zonas de operación) y sin necesidad de que lo autorice la empresa El cambio se debe hacer siempre desde la línea particular |
# | ATOS | Movimientos línea/Tarjetas/ICC/Cambio |
# ]
# chunk: [Codificación activación Duo (Autónomos). Esta llamada se codifica:
# ===
#
# Tramitación / Servicios / Línea Múltiple / Dúo / Alta
#
# Tramitación / Servicios / Línea Múltiple / Dúo / Baja
#
# Seleccionar tipo de Servicio Dúo
#
# En el caso del Alta se deberá introducir el tfno asociado
# ]
# chunk: [Codificación activación Duo (Autónomos). Esta llamada se codifica:
# ===
#
# Tramitación / Servicios / Línea Múltiple / Dúo / Alta
#
# Tramitación / Servicios / Línea Múltiple / Dúo / Baja
#
# Seleccionar tipo de Servicio Dúo
#
# En el caso del Alta se deberá introducir el tfno asociado
# ]
# chunk: [Informacion sobre Datos (Móvil). ?Qué es enviar/recibir Datos
# ===
#
# ?Qué es enviar/recibir Datos?
#
# Todos los clientes pueden enviar/recibir datos a cualquier destino Nacional o Internacional, desde el momento en el que dan de alta su línea Movistar, es decir, navegar por Internet, conectarse a Intranet, consultar/responder correo electrónico?
#
# Se puede enviar y recibir Datos en el propio móvil, en un teléfono MS conectado a un PC/portátil/PDA ó en una PDA si lleva incorporada una tarjeta SIM
#
# ?Necesito una línea exclusiva para enviar/recibir Datos?
#
# Depende del uso que el cliente haga:
#
# ? UNA LÍNEA SÓLO PARA DATOS Cliente que necesita estar constantemente conectado a Internet (p ej un agente de bolsa que trabaja en movilidad, un comercial que hace los pedidos contra el stock del almacén?)
#
# En este caso le interesa el contrato Plus Datos / Plus Datos UMTS, opcionalmente para este último podrá contratar el Módulo C o la Tarifa plana datos
#
# ? UNA SÓLA LÍNEA PARA VOZ y DATOS Si sólo se conecta a Internet puntualmente, o utiliza e-moción, con su línea de voz será suficiente, es recomendable contratar un módulo de datos para que le cueste más barato el tráfico de datos
#
# GSM, GPRS, UMTS
#
# GSM, GPRS y UMTS son tecnologías, sistemas de telefonía móvil digital
#
# ? GSM fue la primera en lanzarse El tráfico de datos lo factura por tiempo de conexión
#
# ? GPRS y UMTS tecnologías que complementan con GSM y que mejoran los servicios de transmisión y recepción de datos El tráfico de datos se factura por volumen de información transmitida (paquetes de información)
#
# Tipos de accesos: ?Wap? y ?Internet/Intranet?
#
# Con nuestro móvil podemos utilizar dos tipos de acceso distintos:
#
# ? Wap es una tecnología desarrollada para el acceso a información y contenidos desde dispositivos móviles (principalmente teléfonos móviles, aunque también se pueden utilizar otros dispositivos como PDAs) Es decir, siempre que accedemos directamente desde nuestro terminal a e-moción o a páginas desarrolladas con esta tecnología estamos utilizando el acceso Wap
#
# ? Internet - es una red compuesta de páginas Web a la que se accede desde un PC (y desde determinados modelos de terminales o PDA´s ) utilizando un móvil como módem mediante un cable de conexión, puerto de infrarrojos o bluetooth o con una tarjeta PCMCIA Estas conexiones y las que realicemos para la consulta de Correo Electrónico las haremos con acceso Internet/Intranet
#
# ? Intranet - la forma de acceder a Intranet es la misma que a Internet, pero no se aacede a páginas web, sino a los servidores corporativos de la empresa Estas conexiones las haremos con acceso Internet/Intranet
#
# ?Cómo veo todo esto en una factura?
#
# ?Y si el cliente tiene un Módulo de Datos?
#
# Lo puedo ver en la pestaña de Servicios/ Serv Valor Añadido
#
# Tarifa Plana Datos
#
# Mód Datos B
# ]
# chunk: [Informacion sobre Datos (Móvil). ?Qué es enviar/recibir Datos
# ===
#
# ?Qué es enviar/recibir Datos?
#
# Todos los clientes pueden enviar/recibir datos a cualquier destino Nacional o Internacional, desde el momento en el que dan de alta su línea Movistar, es decir, navegar por Internet, conectarse a Intranet, consultar/responder correo electrónico?
#
# Se puede enviar y recibir Datos en el propio móvil, en un teléfono MS conectado a un PC/portátil/PDA ó en una PDA si lleva incorporada una tarjeta SIM
#
# ?Necesito una línea exclusiva para enviar/recibir Datos?
#
# Depende del uso que el cliente haga:
#
# ? UNA LÍNEA SÓLO PARA DATOS Cliente que necesita estar constantemente conectado a Internet (p ej un agente de bolsa que trabaja en movilidad, un comercial que hace los pedidos contra el stock del almacén?)
#
# En este caso le interesa el contrato Plus Datos / Plus Datos UMTS, opcionalmente para este último podrá contratar el Módulo C o la Tarifa plana datos
#
# ? UNA SÓLA LÍNEA PARA VOZ y DATOS Si sólo se conecta a Internet puntualmente, o utiliza e-moción, con su línea de voz será suficiente, es recomendable contratar un módulo de datos para que le cueste más barato el tráfico de datos
#
# GSM, GPRS, UMTS
#
# GSM, GPRS y UMTS son tecnologías, sistemas de telefonía móvil digital
#
# ? GSM fue la primera en lanzarse El tráfico de datos lo factura por tiempo de conexión
#
# ? GPRS y UMTS tecnologías que complementan con GSM y que mejoran los servicios de transmisión y recepción de datos El tráfico de datos se factura por volumen de información transmitida (paquetes de información)
#
# Tipos de accesos: ?Wap? y ?Internet/Intranet?
#
# Con nuestro móvil podemos utilizar dos tipos de acceso distintos:
#
# ? Wap es una tecnología desarrollada para el acceso a información y contenidos desde dispositivos móviles (principalmente teléfonos móviles, aunque también se pueden utilizar otros dispositivos como PDAs) Es decir, siempre que accedemos directamente desde nuestro terminal a e-moción o a páginas desarrolladas con esta tecnología estamos utilizando el acceso Wap
#
# ? Internet - es una red compuesta de páginas Web a la que se accede desde un PC (y desde determinados modelos de terminales o PDA´s ) utilizando un móvil como módem mediante un cable de conexión, puerto de infrarrojos o bluetooth o con una tarjeta PCMCIA Estas conexiones y las que realicemos para la consulta de Correo Electrónico las haremos con acceso Internet/Intranet
#
# ? Intranet - la forma de acceder a Intranet es la misma que a Internet, pero no se aacede a páginas web, sino a los servidores corporativos de la empresa Estas conexiones las haremos con acceso Internet/Intranet
#
# ?Cómo veo todo esto en una factura?
#
# ?Y si el cliente tiene un Módulo de Datos?
#
# Lo puedo ver en la pestaña de Servicios/ Serv Valor Añadido
#
# Tarifa Plana Datos
#
# Mód Datos B
# ]
# chunk: [E_Mails. Descripción
# ===
#
# ||
# | - |
# | Debemos enviar un email a las D T siempre que el cliente solicite la activacion de algun servicio que nosotros no podamos activarlo con las herramientas que tenemos, como un Servicio Integra, Instalacion de un Enlace, etc En estos casos debemos: Indicar el Titular y Cif del cliente Responsable de Número de Atención Personal y Tfno de Contacto Breve descripción de lo que el cliente solicita Si la peticion fuera urgente, lo indicariais en el asunto de email ( URGENTE!!!!!! ) Firma siempre todos los correos con TU NOMBRE Y APELLIDOS Siempre debemos tener una respuesta de la D T , el plazo de respuesta debe ser en 1 dia |
# | |
# ]
# chunk: [E_Mails. Descripción
# ===
#
# ||
# | - |
# | Debemos enviar un email a las D T siempre que el cliente solicite la activacion de algun servicio que nosotros no podamos activarlo con las herramientas que tenemos, como un Servicio Integra, Instalacion de un Enlace, etc En estos casos debemos: Indicar el Titular y Cif del cliente Responsable de Número de Atención Personal y Tfno de Contacto Breve descripción de lo que el cliente solicita Si la peticion fuera urgente, lo indicariais en el asunto de email ( URGENTE!!!!!! ) Firma siempre todos los correos con TU NOMBRE Y APELLIDOS Siempre debemos tener una respuesta de la D T , el plazo de respuesta debe ser en 1 dia |
# | |
# ]
# chunk: [Tabla Resumen de Errores (Móvil).
# ||||
# | - | - | - |
# | ERROR EN: | MENSAJE DE ERROR | SOLUCIÓN |
# | Instalación | Error de seguridad de instanlación Imposible de instalar | En el menú principal debe seleccionar Herramientas>Gestor de aplicaciones>Opciones>Ajustes>Instalación del Software>Opciones>Cambiar Asegurate que está activo |
# | Conexión Bluetooth | La conexión con Bluetooth está ocupada | Asegurarse de que el teléfono móvil y/o eñ receptor GPS no está conectado a otro dispositivo Bluethooth Intentar de nuevo conectar con el receptor GPS correcto |
# || Error de conexión con Bluetooth Error de ejecución de Bluetooth | Comprobar lo siguiente: 1 Si Bluetooth está activado en el teléfono móvil y que el receptor Bluetooth de GPS está encendido 2 Situar el receptor Bluetooth de GPS no más lejos de 10 metros del teléfono móvil 3 Que tu teléfono móvil no está conectado a otro dispositivo Bluetooth 4 Que la opción de reconexión GPS automática está desactivada/off 5 Intentar conectar con el receptor Bluetooth de nuevo |
# || Bluetooth desconectado | Comprobar que el receptor GPS está encendido y no más lejos de 10 metros del teléfono móvil e intentar conectar de nuevo con el receptor GPS Y activar Bluetooth en el teléfono móvil |
# || Error de recepción de Bluetooth | Es debido a que RutaMoviStar no recibe datos del GPS Intentar iniciar la aplicación RutaMoviStar y/o el receptor GPS de nuevo |
# | Receptor GPS | No hay datos GPS | Puede ser debido a la comunicación Bluetooth y/o a la recepción GPS Comprobar: 1 Que el receptor GPS está encendido, la baterúia está cargada y el teléfono m´voil está conectado al receptor Bluetooth del GPS 2 Que la distancia entre el receptor GPS y el teléfno móvil no es superior a 10 m 3 Que el recpetor GPS pueda recibir las señales de los satélites, para ello deberá estar al aire o junto a una ventana 4 - Que el GPS conecta con el satélite En caso contrario, o en caso de no responder, remitir al Distribuidor o al Servicio Técnico del equipo |
# | Respuesta tras la búsqueda | Búsqueda devuelta, ninguna coincidencia | El principal motivo es porque uno de los tres campos necesarios no están rellenados con la información: Dirección/Empresa, Ciudad/código postal, País (en el primer y segundo campo sólo hay que introducir uno de los dos datos que se pide, es decir, o la dirección o la Empresa, o la ciudad o el código postal) También puede ser debido a que la ortografía no es correcta O que el país seleccionado no sea el correcto |
# | Instalación de RutaMoviStar | \*El archivo que contiene sonidos está corrupto \*El archivo que contiene gráficos está corrupto \*Los recursos que dependen del lenguaje para El lenguaje activo no se han instalado correctamente El audio va a ser inhabilitado \*Error de idioma en la instalación El programa finalizará \*La instalación está dañada y el programa se cerrará | 1 Cerrar la aplicación RutaMoviStar 2 En el menú principal del tléfono seleccionar Herramientas>Opciones>Abrir 3 Marcar uno de los ficheros existentes y presionar Opciones>Quitar Es muy importante que borre todos los ficheros actuales 4 Reinstalar RutaMoviStar |
# | GPRS | \*No se ha encontrado el servidor Comprueba tus ajustes de Internet \*Error de red Comprueba tus ajustes de Internet \*Conexión falló, comprueba la red | Puede ser debido a los siguientes motivos: 1 No tiene GPRS activado y/o configurado su terminal Activar este servicio si es así y/o configurar el terminal 2 Problemas en la red GPRS |
# || \*Finalización de tiempo de servidor interno \*El servidor no responde Inténtalo de nuevo \*Se ha roto la comunicación con el servidor Inténtalo de nuevo \*Finalización de tiempo en la comunicación del servidor | Son mensajes de error temporal con duración corta y probablemente habrán terminado si lo intenta de nuevo |
# | Memoria | \*No hay suficiente memoria disponible, el programa se cerrará \*No queda más espacio en el dispositivo Cerrando el programa | Eliminar datos de la memoria del terminal para incrementar su capacidad y poder realizar la acción solicitada |
# | Favoritos (web) | Sincronización de Favoritos en progreso | Esperar hasta que haya finalizado la sincronización |
# || Favoritos están corruptos | Sleccionar Sincronizar para actualizar la información disopnible sobre tus Favoritos |
# | Otros | No hay destino a la ruta hacia | No se ha establecido un destino y por lo tanto RutaMoviStar no puede calcular la ruta Se ha de definir el destino |
# || Origen no establecido | Se está calculando una ruta sin estar conectado al receptor GPS y por lo tanto hay que definir el origen y el destino |
# || Ruta demasiado larga para el tipo de vehículo | Probablemente tenga seleccionado como tipo de vehículo "peatón" y la ruta es demasiado larga (más de 10 kms) Se deberá cambiar a Automóvil o a Taxi |
# ]
# chunk: [Tabla Resumen de Errores (Móvil).
# ||||
# | - | - | - |
# | ERROR EN: | MENSAJE DE ERROR | SOLUCIÓN |
# | Instalación | Error de seguridad de instanlación Imposible de instalar | En el menú principal debe seleccionar Herramientas>Gestor de aplicaciones>Opciones>Ajustes>Instalación del Software>Opciones>Cambiar Asegurate que está activo |
# | Conexión Bluetooth | La conexión con Bluetooth está ocupada | Asegurarse de que el teléfono móvil y/o eñ receptor GPS no está conectado a otro dispositivo Bluethooth Intentar de nuevo conectar con el receptor GPS correcto |
# || Error de conexión con Bluetooth Error de ejecución de Bluetooth | Comprobar lo siguiente: 1 Si Bluetooth está activado en el teléfono móvil y que el receptor Bluetooth de GPS está encendido 2 Situar el receptor Bluetooth de GPS no más lejos de 10 metros del teléfono móvil 3 Que tu teléfono móvil no está conectado a otro dispositivo Bluetooth 4 Que la opción de reconexión GPS automática está desactivada/off 5 Intentar conectar con el receptor Bluetooth de nuevo |
# || Bluetooth desconectado | Comprobar que el receptor GPS está encendido y no más lejos de 10 metros del teléfono móvil e intentar conectar de nuevo con el receptor GPS Y activar Bluetooth en el teléfono móvil |
# || Error de recepción de Bluetooth | Es debido a que RutaMoviStar no recibe datos del GPS Intentar iniciar la aplicación RutaMoviStar y/o el receptor GPS de nuevo |
# | Receptor GPS | No hay datos GPS | Puede ser debido a la comunicación Bluetooth y/o a la recepción GPS Comprobar: 1 Que el receptor GPS está encendido, la baterúia está cargada y el teléfono m´voil está conectado al receptor Bluetooth del GPS 2 Que la distancia entre el receptor GPS y el teléfno móvil no es superior a 10 m 3 Que el recpetor GPS pueda recibir las señales de los satélites, para ello deberá estar al aire o junto a una ventana 4 - Que el GPS conecta con el satélite En caso contrario, o en caso de no responder, remitir al Distribuidor o al Servicio Técnico del equipo |
# | Respuesta tras la búsqueda | Búsqueda devuelta, ninguna coincidencia | El principal motivo es porque uno de los tres campos necesarios no están rellenados con la información: Dirección/Empresa, Ciudad/código postal, País (en el primer y segundo campo sólo hay que introducir uno de los dos datos que se pide, es decir, o la dirección o la Empresa, o la ciudad o el código postal) También puede ser debido a que la ortografía no es correcta O que el país seleccionado no sea el correcto |
# | Instalación de RutaMoviStar | \*El archivo que contiene sonidos está corrupto \*El archivo que contiene gráficos está corrupto \*Los recursos que dependen del lenguaje para El lenguaje activo no se han instalado correctamente El audio va a ser inhabilitado \*Error de idioma en la instalación El programa finalizará \*La instalación está dañada y el programa se cerrará | 1 Cerrar la aplicación RutaMoviStar 2 En el menú principal del tléfono seleccionar Herramientas>Opciones>Abrir 3 Marcar uno de los ficheros existentes y presionar Opciones>Quitar Es muy importante que borre todos los ficheros actuales 4 Reinstalar RutaMoviStar |
# | GPRS | \*No se ha encontrado el servidor Comprueba tus ajustes de Internet \*Error de red Comprueba tus ajustes de Internet \*Conexión falló, comprueba la red | Puede ser debido a los siguientes motivos: 1 No tiene GPRS activado y/o configurado su terminal Activar este servicio si es así y/o configurar el terminal 2 Problemas en la red GPRS |
# || \*Finalización de tiempo de servidor interno \*El servidor no responde Inténtalo de nuevo \*Se ha roto la comunicación con el servidor Inténtalo de nuevo \*Finalización de tiempo en la comunicación del servidor | Son mensajes de error temporal con duración corta y probablemente habrán terminado si lo intenta de nuevo |
# | Memoria | \*No hay suficiente memoria disponible, el programa se cerrará \*No queda más espacio en el dispositivo Cerrando el programa | Eliminar datos de la memoria del terminal para incrementar su capacidad y poder realizar la acción solicitada |
# | Favoritos (web) | Sincronización de Favoritos en progreso | Esperar hasta que haya finalizado la sincronización |
# || Favoritos están corruptos | Sleccionar Sincronizar para actualizar la información disopnible sobre tus Favoritos |
# | Otros | No hay destino a la ruta hacia | No se ha establecido un destino y por lo tanto RutaMoviStar no puede calcular la ruta Se ha de definir el destino |
# || Origen no establecido | Se está calculando una ruta sin estar conectado al receptor GPS y por lo tanto hay que definir el origen y el destino |
# || Ruta demasiado larga para el tipo de vehículo | Probablemente tenga seleccionado como tipo de vehículo "peatón" y la ruta es demasiado larga (más de 10 kms) Se deberá cambiar a Automóvil o a Taxi |
# ]
# chunk: [Mensajeria Plural/ Directa Terminales Compatibles (Móvil). FABRICANTES
# ===
#
# |||
# | - | - |
# | FABRICANTES | MODELOS |
# | ALCATEL | ONE TOUCH 535,ONE TOUCH 715,ONE TOUCH 735,ONE TOUCH POCKET, 735 i |
# | LG | G510, G7200 |
# | MOTOROLA | LSERIES,SMART CELLECT,STARTAC130, C350 - C333 - V70 y V66 i |
# | NEC | N331 i |
# | NOKIA | 5110,6100,6110,6150,6210,6310I,6510,7110,8310,CELLULAR DATA ADAPTER FOR GSM AND PCN/DCS 1800 (PREMICELL),CELLULAR DATA SUITE 3 0, 6310 - 6310 i - 7210 i |
# | PHIILIPS | 535 |
# | NOVATEL | Merlin U530 |
# | SAGEM | MYX3-D,MYX-6 |
# | SAMSUNG | V200 |
# | SIEMENS | C35I,C45,C55,M1,M20,M55,MC35,ME45,S35,S45,S55, SL 45 |
# | SIERRA WIRELESS | AIRCARD? 750 WIRELESS NETWORK CARD,WIRELESS AIRCARD 750 |
# | SONY-ERICSSON | T300, T68 i |
# | WAVECOM | GSM MÃ“DEM WM01-6906 (WISMO),WM1080A MULTIBAND 900E 1800,WMO2 900P,WMOD2 MULTIBAND 900E 1800,WMOD240 MULTIBAND 900E 1800 |
# ]
# chunk: [Mensajeria Plural/ Directa Terminales Compatibles (Móvil). FABRICANTES
# ===
#
# |||
# | - | - |
# | FABRICANTES | MODELOS |
# | ALCATEL | ONE TOUCH 535,ONE TOUCH 715,ONE TOUCH 735,ONE TOUCH POCKET, 735 i |
# | LG | G510, G7200 |
# | MOTOROLA | LSERIES,SMART CELLECT,STARTAC130, C350 - C333 - V70 y V66 i |
# | NEC | N331 i |
# | NOKIA | 5110,6100,6110,6150,6210,6310I,6510,7110,8310,CELLULAR DATA ADAPTER FOR GSM AND PCN/DCS 1800 (PREMICELL),CELLULAR DATA SUITE 3 0, 6310 - 6310 i - 7210 i |
# | PHIILIPS | 535 |
# | NOVATEL | Merlin U530 |
# | SAGEM | MYX3-D,MYX-6 |
# | SAMSUNG | V200 |
# | SIEMENS | C35I,C45,C55,M1,M20,M55,MC35,ME45,S35,S45,S55, SL 45 |
# | SIERRA WIRELESS | AIRCARD? 750 WIRELESS NETWORK CARD,WIRELESS AIRCARD 750 |
# | SONY-ERICSSON | T300, T68 i |
# | WAVECOM | GSM MÃ“DEM WM01-6906 (WISMO),WM1080A MULTIBAND 900E 1800,WMO2 900P,WMOD2 MULTIBAND 900E 1800,WMOD240 MULTIBAND 900E 1800 |
# ]
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 100,
# 	answer: "Para solicitar el patrocinio de un evento por parte de Telefónica Móviles, los clientes interesados deben enviar un dossier completo con todos los datos por correo a Francisco García del Pozo o Rocío Vallejo-Nagera en la dirección: Telefónica Móviles España Distrito C, Edificio Sur 1, Planta 4 C/ Ronda de la Comunicación s/n 28050 Madrid."
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
# 	confidence: 0,
# 	answer: ""
#
# ANSWER: ((114975)) Para solicitar el patrocinio de un evento por parte de Telefónica Móviles, los clientes interesados deben enviar un dossier completo con todos los datos por correo a Francisco García del Pozo o Rocío Vallejo-Nagera en la dirección: Telefónica Móviles España Distrito C, Edificio Sur 1, Planta 4 C/ Ronda de la Comunicación s/n 28050 Madrid. ((114975))
